# %%
import numpy as np
import sys
sys.path.append('..')
from custom_lib import quantum_circuit_ctx_generator, utils, verilog

# %%
min_qbit_num = 3
max_qbit_num = 17
min_quantum_circuit_idx = 1
max_quantum_circuit_idx = 19

quantum_circuit_idx_range = np.arange(min_quantum_circuit_idx, max_quantum_circuit_idx+1, 1)
qubit_num_idx_range = np.arange(min_qbit_num, max_qbit_num+1, 1)

hard_results = []
soft_results = []
final_results = []

utils.create_folder('./ET_Result')
for qubit_num_idx in qubit_num_idx_range:
    saved_folder_name_hard = '../hardware/verilog/generated_sim_file/quantum_circuit_data_' + str(qubit_num_idx) + '_qubits/'
    for quantum_circuit_idx in quantum_circuit_idx_range:
        saved_sub_folder_name_hard = saved_folder_name_hard + 'quanvolutional_' + str(quantum_circuit_idx)

        hard_data = utils.read_file(saved_sub_folder_name_hard + '/timestamps_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt')
        hard_res = float(hard_data[2].strip("").split(' ')[3][:-3])/1000000000
        res = str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + ": " + str(hard_res) + "(s)"
        hard_results.append(res)

        soft_file_name = "../result/quanv/quanv" + str(quantum_circuit_idx) + ".txt"
        soft_data = utils.read_file(soft_file_name)
        soft_res = float(soft_data[qubit_num_idx-3])
        res = str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + ": " + str(soft_res) + "(s)"
        soft_results.append(res)

        print(f"====================== {qubit_num_idx} qbits, quanv{quantum_circuit_idx} circuit ======================")
        print(f"Hardware Result: {hard_res}(s) | Software Result: {soft_res}(s) | Compare: {soft_res/hard_res}")
        final_results.append(f"====================== {qubit_num_idx} qbits, quanv{quantum_circuit_idx} circuit ======================")
        final_results.append(f"Hardware Result: {hard_res}(s) | Software Result: {soft_res}(s) | Compare: {soft_res/hard_res}")

utils.write_file('./ET_Result/hardware_results.txt', hard_results)
utils.write_file('./ET_Result/software_results.txt', soft_results)
utils.write_file('./ET_Result/final_results.txt', final_results)



# for qubit_num_idx in qubit_num_idx_range:
#     saved_folder = './test_quantum_circuit_data_' + str(qubit_num_idx) + '_qubits/'
#     utils.create_folder(saved_folder)
#     for quantum_circuit_idx in quantum_circuit_idx_range:
#         raw_file_path = saved_folder + 'test_output_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         state_res_file_path = saved_folder + 'test_state_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         processed_file_path = saved_folder + 'test_output_hex_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         quantum_circuit_ctx_generator.generate_quantum_circuit_data_with_state_res(num_qubits=qubit_num_idx, quanvolutional_idx=quantum_circuit_idx, basis_gate_list=['h', 's', 'cx', 'rx', 'ry', 'rz'], output_file_path=raw_file_path, output_state_path=state_res_file_path)
#         quantum_circuit_ctx_generator.generate_quantum_circuit_ctx(bit_width=32, fraction_width=30, raw_file_path=raw_file_path, processed_file_path=processed_file_path)
# Out:
# ====================== 3 qbits, quanv1 circuit ======================
# Hardware Result: 6.52e-07(s) | Software Result: 5.169494867324829(s) | Compare: 7928673.1093939105
# ====================== 3 qbits, quanv2 circuit ======================
# Hardware Result: 8.52e-07(s) | Software Result: 0.013569355010986328(s) | Compare: 15926.473017589587
# ====================== 3 qbits, quanv3 circuit ======================
# Hardware Result: 1.7e-06(s) | Software Result: 0.021537303924560547(s) | Compare: 12669.002308565028
# ====================== 3 qbits, quanv4 circuit ======================
# Hardware Result: 1.7e-06(s) | Software Result: 0.020219802856445312(s) | Compare: 11894.001680261948
# ====================== 3 qbits, quanv5 circuit ======================
# Hardware Result: 3.536e-06(s) | Software Result: 0.04025840759277344(s) | Compare: 11385.296264924615
# ====================== 3 qbits, quanv6 circuit ======================
# Hardware Result: 3.752e-06(s) | Software Result: 0.03961467742919922(s) | Compare: 10558.282896908107
# ====================== 3 qbits, quanv7 circuit ======================
# Hardware Result: 1.808e-06(s) | Software Result: 0.022774696350097656(s) | Compare: 12596.624087443393
# ====================== 3 qbits, quanv8 circuit ======================
# Hardware Result: 2.024e-06(s) | Software Result: 0.022004365921020508(s) | Compare: 10871.722292994322
# ====================== 3 qbits, quanv9 circuit ======================
# Hardware Result: 8.52e-07(s) | Software Result: 0.011883974075317383(s) | Compare: 13948.326379480497
# ====================== 3 qbits, quanv10 circuit ======================
# Hardware Result: 1.616e-06(s) | Software Result: 0.016213655471801758(s) | Compare: 10033.202643441682
# ====================== 3 qbits, quanv11 circuit ======================
# Hardware Result: 9.52e-07(s) | Software Result: 0.0122833251953125(s) | Compare: 12902.65251608456
# ====================== 3 qbits, quanv12 circuit ======================
# Hardware Result: 1.06e-06(s) | Software Result: 0.01423501968383789(s) | Compare: 13429.263852677255
# ====================== 3 qbits, quanv13 circuit ======================
# Hardware Result: 3.66e-06(s) | Software Result: 0.03386354446411133(s) | Compare: 9252.334553035882
# ====================== 3 qbits, quanv14 circuit ======================
# Hardware Result: 4.74e-06(s) | Software Result: 0.038482666015625(s) | Compare: 8118.705910469409
# ====================== 3 qbits, quanv15 circuit ======================
# Hardware Result: 1.4e-06(s) | Software Result: 0.0145416259765625(s) | Compare: 10386.875697544643
# ====================== 3 qbits, quanv16 circuit ======================
# Hardware Result: 1.268e-06(s) | Software Result: 0.019971609115600586(s) | Compare: 15750.480375079327
# ====================== 3 qbits, quanv17 circuit ======================
# Hardware Result: 1.7e-06(s) | Software Result: 0.021950960159301758(s) | Compare: 12912.329505471622
# ====================== 3 qbits, quanv18 circuit ======================
# Hardware Result: 1.608e-06(s) | Software Result: 0.024737119674682617(s) | Compare: 15383.780892215556
# ====================== 3 qbits, quanv19 circuit ======================
# Hardware Result: 2.256e-06(s) | Software Result: 0.027683734893798828(s) | Compare: 12271.159084130686
# ====================== 4 qbits, quanv1 circuit ======================
# Hardware Result: 9.32e-07(s) | Software Result: 0.016879558563232422(s) | Compare: 18111.11433823221
# ====================== 4 qbits, quanv2 circuit ======================
# Hardware Result: 1.408e-06(s) | Software Result: 0.012811660766601562(s) | Compare: 9099.190885370428
# ====================== 4 qbits, quanv3 circuit ======================
# Hardware Result: 2.928e-06(s) | Software Result: 0.024077415466308594(s) | Compare: 8223.161019914136
# ====================== 4 qbits, quanv4 circuit ======================
# Hardware Result: 2.928e-06(s) | Software Result: 0.023810863494873047(s) | Compare: 8132.125510544073
# ====================== 4 qbits, quanv5 circuit ======================
# Hardware Result: 8.116e-06(s) | Software Result: 0.05632209777832031(s) | Compare: 6939.637478846761
# ====================== 4 qbits, quanv6 circuit ======================
# Hardware Result: 8.348e-06(s) | Software Result: 0.05040311813354492(s) | Compare: 6037.747740002985
# ====================== 4 qbits, quanv7 circuit ======================
# Hardware Result: 3.16e-06(s) | Software Result: 0.025584697723388672(s) | Compare: 8096.423330186289
# ====================== 4 qbits, quanv8 circuit ======================
# Hardware Result: 3.392e-06(s) | Software Result: 0.028273344039916992(s) | Compare: 8335.301898560434
# ====================== 4 qbits, quanv9 circuit ======================
# Hardware Result: 1.408e-06(s) | Software Result: 0.01443624496459961(s) | Compare: 10253.014889630405
# ====================== 4 qbits, quanv10 circuit ======================
# Hardware Result: 2.516e-06(s) | Software Result: 0.01814579963684082(s) | Compare: 7212.162017822266
# ====================== 4 qbits, quanv11 circuit ======================
# Hardware Result: 1.872e-06(s) | Software Result: 0.015352487564086914(s) | Compare: 8201.11515175583
# ====================== 4 qbits, quanv12 circuit ======================
# Hardware Result: 2.104e-06(s) | Software Result: 0.02079033851623535(s) | Compare: 9881.339598971173
# ====================== 4 qbits, quanv13 circuit ======================
# Hardware Result: 5.412e-06(s) | Software Result: 0.03767967224121094(s) | Compare: 6962.245425205273
# ====================== 4 qbits, quanv14 circuit ======================
# Hardware Result: 7.036e-06(s) | Software Result: 0.0408635139465332(s) | Compare: 5807.77628574946
# ====================== 4 qbits, quanv15 circuit ======================
# Hardware Result: 2.244e-06(s) | Software Result: 0.015345335006713867(s) | Compare: 6838.384584097089
# ====================== 4 qbits, quanv16 circuit ======================
# Hardware Result: 2.232e-06(s) | Software Result: 0.023574113845825195(s) | Compare: 10561.878963183332
# ====================== 4 qbits, quanv17 circuit ======================
# Hardware Result: 2.928e-06(s) | Software Result: 0.026137351989746094(s) | Compare: 8926.691253328583
# ====================== 4 qbits, quanv18 circuit ======================
# Hardware Result: 2.708e-06(s) | Software Result: 0.030254602432250977(s) | Compare: 11172.305181776579
# ====================== 4 qbits, quanv19 circuit ======================
# Hardware Result: 3.636e-06(s) | Software Result: 0.03266000747680664(s) | Compare: 8982.400296151442
# ====================== 5 qbits, quanv1 circuit ======================
# Hardware Result: 1.324e-06(s) | Software Result: 0.010624408721923828(s) | Compare: 8024.477886649417
# ====================== 5 qbits, quanv2 circuit ======================
# Hardware Result: 2.428e-06(s) | Software Result: 0.014352083206176758(s) | Compare: 5911.07216069883
# ====================== 5 qbits, quanv3 circuit ======================
# Hardware Result: 5.116e-06(s) | Software Result: 0.028917312622070312(s) | Compare: 5652.328503141187
# ====================== 5 qbits, quanv4 circuit ======================
# Hardware Result: 5.116e-06(s) | Software Result: 0.028462648391723633(s) | Compare: 5563.457465153173
# ====================== 5 qbits, quanv5 circuit ======================
# Hardware Result: 1.856e-05(s) | Software Result: 0.06835293769836426(s) | Compare: 3682.8091432308333
# ====================== 5 qbits, quanv6 circuit ======================
# Hardware Result: 1.8824e-05(s) | Software Result: 0.05266714096069336(s) | Compare: 2797.871916738916
# ====================== 5 qbits, quanv7 circuit ======================
# Hardware Result: 5.248e-06(s) | Software Result: 0.030487060546875(s) | Compare: 5809.2722078649
# ====================== 5 qbits, quanv8 circuit ======================
# Hardware Result: 5.776e-06(s) | Software Result: 0.03166341781616211(s) | Compare: 5481.893666233052
# ====================== 5 qbits, quanv9 circuit ======================
# Hardware Result: 2.428e-06(s) | Software Result: 0.015927791595458984(s) | Compare: 6560.045961885909
# ====================== 5 qbits, quanv10 circuit ======================
# Hardware Result: 4.056e-06(s) | Software Result: 0.020685672760009766(s) | Compare: 5100.017938858424
# ====================== 5 qbits, quanv11 circuit ======================
# Hardware Result: 2.912e-06(s) | Software Result: 0.016795635223388672(s) | Compare: 5767.7318761636925
# ====================== 5 qbits, quanv12 circuit ======================
# Hardware Result: 3.176e-06(s) | Software Result: 0.022063016891479492(s) | Compare: 6946.793731574147
# ====================== 5 qbits, quanv13 circuit ======================
# Hardware Result: 8.732e-06(s) | Software Result: 0.027671337127685547(s) | Compare: 3168.9575272200577
# ====================== 5 qbits, quanv14 circuit ======================
# Hardware Result: 1.0844e-05(s) | Software Result: 0.0278170108795166(s) | Compare: 2565.1983474286794
# ====================== 5 qbits, quanv15 circuit ======================
# Hardware Result: 3.84e-06(s) | Software Result: 0.017536640167236328(s) | Compare: 4566.83337688446
# ====================== 5 qbits, quanv16 circuit ======================
# Hardware Result: 4.06e-06(s) | Software Result: 0.029399871826171875(s) | Compare: 7241.347740436422
# ====================== 5 qbits, quanv17 circuit ======================
# Hardware Result: 5.116e-06(s) | Software Result: 0.031142473220825195(s) | Compare: 6087.269980614777
# ====================== 5 qbits, quanv18 circuit ======================
# Hardware Result: 4.808e-06(s) | Software Result: 0.03150796890258789(s) | Compare: 6553.238124498313
# ====================== 5 qbits, quanv19 circuit ======================
# Hardware Result: 6.128e-06(s) | Software Result: 0.030350685119628906(s) | Compare: 4952.7880417149
# ====================== 6 qbits, quanv1 circuit ======================
# Hardware Result: 1.972e-06(s) | Software Result: 0.009412288665771484(s) | Compare: 4772.9658548536945
# ====================== 6 qbits, quanv2 circuit ======================
# Hardware Result: 4.536e-06(s) | Software Result: 0.015865325927734375(s) | Compare: 3497.64680946525
# ====================== 6 qbits, quanv3 circuit ======================
# Hardware Result: 9.56e-06(s) | Software Result: 0.02084183692932129(s) | Compare: 2180.108465410177
# ====================== 6 qbits, quanv4 circuit ======================
# Hardware Result: 9.56e-06(s) | Software Result: 0.021497726440429688(s) | Compare: 2248.716154856662
# ====================== 6 qbits, quanv5 circuit ======================
# Hardware Result: 4.4076e-05(s) | Software Result: 0.10266566276550293(s) | Compare: 2329.2872031378283
# ====================== 6 qbits, quanv6 circuit ======================
# Hardware Result: 4.4404e-05(s) | Software Result: 0.07167625427246094(s) | Compare: 1614.1846291428913
# ====================== 6 qbits, quanv7 circuit ======================
# Hardware Result: 9.888e-06(s) | Software Result: 0.021383047103881836(s) | Compare: 2162.524990279312
# ====================== 6 qbits, quanv8 circuit ======================
# Hardware Result: 1.0544e-05(s) | Software Result: 0.023375511169433594(s) | Compare: 2216.949086630652
# ====================== 6 qbits, quanv9 circuit ======================
# Hardware Result: 4.536e-06(s) | Software Result: 0.017788171768188477(s) | Compare: 3921.554622616507
# ====================== 6 qbits, quanv10 circuit ======================
# Hardware Result: 7.068e-06(s) | Software Result: 0.023311138153076172(s) | Compare: 3298.1236775716147
# ====================== 6 qbits, quanv11 circuit ======================
# Hardware Result: 5.848e-06(s) | Software Result: 0.021158933639526367(s) | Compare: 3618.1487071693514
# ====================== 6 qbits, quanv12 circuit ======================
# Hardware Result: 6.34e-06(s) | Software Result: 0.0258026123046875(s) | Compare: 4069.812666354495
# ====================== 6 qbits, quanv13 circuit ======================
# Hardware Result: 1.5508e-05(s) | Software Result: 0.027045488357543945(s) | Compare: 1743.9701030141825
# ====================== 6 qbits, quanv14 circuit ======================
# Hardware Result: 1.846e-05(s) | Software Result: 0.030523300170898438(s) | Compare: 1653.4832161916813
# ====================== 6 qbits, quanv15 circuit ======================
# Hardware Result: 7.1e-06(s) | Software Result: 0.01937270164489746(s) | Compare: 2728.549527450347
# ====================== 6 qbits, quanv16 circuit ======================
# Hardware Result: 7.92e-06(s) | Software Result: 0.02183079719543457(s) | Compare: 2756.4137873023446
# ====================== 6 qbits, quanv17 circuit ======================
# Hardware Result: 9.56e-06(s) | Software Result: 0.021791458129882812(s) | Compare: 2279.4412269751897
# ====================== 6 qbits, quanv18 circuit ======================
# Hardware Result: 9.212e-06(s) | Software Result: 0.025348424911499023(s) | Compare: 2751.6744367671545
# ====================== 6 qbits, quanv19 circuit ======================
# Hardware Result: 1.118e-05(s) | Software Result: 0.026526927947998047(s) | Compare: 2372.7126966008987
# ====================== 7 qbits, quanv1 circuit ======================
# Hardware Result: 3.196e-06(s) | Software Result: 0.008066654205322266(s) | Compare: 2523.984419687818
# ====================== 7 qbits, quanv2 circuit ======================
# Hardware Result: 9.14e-06(s) | Software Result: 0.017455101013183594(s) | Compare: 1909.748469713741
# ====================== 7 qbits, quanv3 circuit ======================
# Hardware Result: 1.9188e-05(s) | Software Result: 0.022205591201782227(s) | Compare: 1157.2644987378687
# ====================== 7 qbits, quanv4 circuit ======================
# Hardware Result: 1.9188e-05(s) | Software Result: 0.0221402645111084(s) | Compare: 1153.8599390821555
# ====================== 7 qbits, quanv5 circuit ======================
# Hardware Result: 0.000108184(s) | Software Result: 0.15100383758544922(s) | Compare: 1395.8056421046476
# ====================== 7 qbits, quanv6 circuit ======================
# Hardware Result: 0.00010864(s) | Software Result: 0.09659314155578613(s) | Compare: 889.1121277226264
# ====================== 7 qbits, quanv7 circuit ======================
# Hardware Result: 1.9416e-05(s) | Software Result: 0.030371427536010742(s) | Compare: 1564.2474009070222
# ====================== 7 qbits, quanv8 circuit ======================
# Hardware Result: 2.0784e-05(s) | Software Result: 0.026802539825439453(s) | Compare: 1289.5756267051315
# ====================== 7 qbits, quanv9 circuit ======================
# Hardware Result: 9.14e-06(s) | Software Result: 0.018929243087768555(s) | Compare: 2071.033160587369
# ====================== 7 qbits, quanv10 circuit ======================
# Hardware Result: 1.3408e-05(s) | Software Result: 0.015444278717041016(s) | Compare: 1151.870429373584
# ====================== 7 qbits, quanv11 circuit ======================
# Hardware Result: 1.0344e-05(s) | Software Result: 0.018259286880493164(s) | Compare: 1765.2056148968643
# ====================== 7 qbits, quanv12 circuit ======================
# Hardware Result: 1.1028e-05(s) | Software Result: 0.01809406280517578(s) | Compare: 1640.73837551467
# ====================== 7 qbits, quanv13 circuit ======================
# Hardware Result: 2.9836e-05(s) | Software Result: 0.03022289276123047(s) | Compare: 1012.9673133540176
# ====================== 7 qbits, quanv14 circuit ======================
# Hardware Result: 3.4396e-05(s) | Software Result: 0.03288626670837402(s) | Compare: 956.1073005109322
# ====================== 7 qbits, quanv15 circuit ======================
# Hardware Result: 1.4008e-05(s) | Software Result: 0.017001628875732422(s) | Compare: 1213.7085148295562
# ====================== 7 qbits, quanv16 circuit ======================
# Hardware Result: 1.6452e-05(s) | Software Result: 0.023632526397705078(s) | Compare: 1436.4530997875686
# ====================== 7 qbits, quanv17 circuit ======================
# Hardware Result: 1.9188e-05(s) | Software Result: 0.025295495986938477(s) | Compare: 1318.2976853730704
# ====================== 7 qbits, quanv18 circuit ======================
# Hardware Result: 1.8832e-05(s) | Software Result: 0.030753612518310547(s) | Compare: 1633.0507921787676
# ====================== 7 qbits, quanv19 circuit ======================
# Hardware Result: 2.2024e-05(s) | Software Result: 0.03079533576965332(s) | Compare: 1398.2626121346402
# ====================== 8 qbits, quanv1 circuit ======================
# Hardware Result: 5.7e-06(s) | Software Result: 0.008358478546142578(s) | Compare: 1466.3997449372946
# ====================== 8 qbits, quanv2 circuit ======================
# Hardware Result: 1.9376e-05(s) | Software Result: 0.012814998626708984(s) | Compare: 661.3851479515372
# ====================== 8 qbits, quanv3 circuit ======================
# Hardware Result: 4.0528e-05(s) | Software Result: 0.02497124671936035(s) | Compare: 616.1480141966134
# ====================== 8 qbits, quanv4 circuit ======================
# Hardware Result: 4.0528e-05(s) | Software Result: 0.03155159950256348(s) | Compare: 778.5136079392882
# ====================== 8 qbits, quanv5 circuit ======================
# Hardware Result: 0.000269284(s) | Software Result: 0.19920992851257324(s) | Compare: 739.7763272699947
# ====================== 8 qbits, quanv6 circuit ======================
# Hardware Result: 0.000269996(s) | Software Result: 0.12694430351257324(s) | Compare: 470.1710525806799
# ====================== 8 qbits, quanv7 circuit ======================
# Hardware Result: 4.124e-05(s) | Software Result: 0.028312206268310547(s) | Compare: 686.5229454003528
# ====================== 8 qbits, quanv8 circuit ======================
# Hardware Result: 4.3376e-05(s) | Software Result: 0.029906511306762695(s) | Compare: 689.4713967807704
# ====================== 8 qbits, quanv9 circuit ======================
# Hardware Result: 1.9376e-05(s) | Software Result: 0.013544797897338867(s) | Compare: 699.0502630748797
# ====================== 8 qbits, quanv10 circuit ======================
# Hardware Result: 2.7172e-05(s) | Software Result: 0.016687393188476562(s) | Compare: 614.1393047429914
# ====================== 8 qbits, quanv11 circuit ======================
# Hardware Result: 2.3648e-05(s) | Software Result: 0.015848636627197266(s) | Compare: 670.1893025709263
# ====================== 8 qbits, quanv12 circuit ======================
# Hardware Result: 2.5072e-05(s) | Software Result: 0.022161245346069336(s) | Compare: 883.9041698336525
# ====================== 8 qbits, quanv13 circuit ======================
# Hardware Result: 6.0548e-05(s) | Software Result: 0.03219318389892578(s) | Compare: 531.6968999624395
# ====================== 8 qbits, quanv14 circuit ======================
# Hardware Result: 6.838e-05(s) | Software Result: 0.03580427169799805(s) | Compare: 523.6073661596672
# ====================== 8 qbits, quanv15 circuit ======================
# Hardware Result: 2.8852e-05(s) | Software Result: 0.01317286491394043(s) | Compare: 456.56678614794225
# ====================== 8 qbits, quanv16 circuit ======================
# Hardware Result: 3.5544e-05(s) | Software Result: 0.02607440948486328(s) | Compare: 733.5811806454897
# ====================== 8 qbits, quanv17 circuit ======================
# Hardware Result: 4.0528e-05(s) | Software Result: 0.028003692626953125(s) | Compare: 690.9714919796961
# ====================== 8 qbits, quanv18 circuit ======================
# Hardware Result: 4.01e-05(s) | Software Result: 0.03953981399536133(s) | Compare: 986.0302741985369
# ====================== 8 qbits, quanv19 circuit ======================
# Hardware Result: 4.5796e-05(s) | Software Result: 0.034958600997924805(s) | Compare: 763.3548999459517
# ====================== 9 qbits, quanv1 circuit ======================
# Hardware Result: 1.102e-05(s) | Software Result: 0.008746623992919922(s) | Compare: 793.7045365626063
# ====================== 9 qbits, quanv2 circuit ======================
# Hardware Result: 4.2156e-05(s) | Software Result: 0.012324094772338867(s) | Compare: 292.3449751479948
# ====================== 9 qbits, quanv3 circuit ======================
# Hardware Result: 8.798e-05(s) | Software Result: 0.027594327926635742(s) | Compare: 313.6431908005881
# ====================== 9 qbits, quanv4 circuit ======================
# Hardware Result: 8.798e-05(s) | Software Result: 0.027780532836914062(s) | Compare: 315.7596367005463
# ====================== 9 qbits, quanv5 circuit ======================
# Hardware Result: 0.0006692(s) | Software Result: 0.2606966495513916(s) | Compare: 389.5646287378834
# ====================== 9 qbits, quanv6 circuit ======================
# Hardware Result: 0.000670424(s) | Software Result: 0.16243863105773926(s) | Compare: 242.29238669519478
# ====================== 9 qbits, quanv7 circuit ======================
# Hardware Result: 8.8592e-05(s) | Software Result: 0.030649900436401367(s) | Compare: 345.96690938686754
# ====================== 9 qbits, quanv8 circuit ======================
# Hardware Result: 9.3488e-05(s) | Software Result: 0.03426766395568848(s) | Compare: 366.5461230926801
# ====================== 9 qbits, quanv9 circuit ======================
# Hardware Result: 4.2156e-05(s) | Software Result: 0.013517141342163086(s) | Compare: 320.6457287732016
# ====================== 9 qbits, quanv10 circuit ======================
# Hardware Result: 5.732e-05(s) | Software Result: 0.018341779708862305(s) | Compare: 319.9891784518895
# ====================== 9 qbits, quanv11 circuit ======================
# Hardware Result: 4.6576e-05(s) | Software Result: 0.016482830047607422(s) | Compare: 353.8910607954187
# ====================== 9 qbits, quanv12 circuit ======================
# Hardware Result: 4.9024e-05(s) | Software Result: 0.02292490005493164(s) | Compare: 467.6260618254659
# ====================== 9 qbits, quanv13 circuit ======================
# Hardware Result: 0.000126588(s) | Software Result: 0.034796953201293945(s) | Compare: 274.8835055557711
# ====================== 9 qbits, quanv14 circuit ======================
# Hardware Result: 0.000141276(s) | Software Result: 0.03866147994995117(s) | Compare: 273.6592198954612
# ====================== 9 qbits, quanv15 circuit ======================
# Hardware Result: 6.0848e-05(s) | Software Result: 0.014075994491577148(s) | Compare: 231.3304380025169
# ====================== 9 qbits, quanv16 circuit ======================
# Hardware Result: 7.8188e-05(s) | Software Result: 0.029360532760620117(s) | Compare: 375.51200645393305
# ====================== 9 qbits, quanv17 circuit ======================
# Hardware Result: 8.798e-05(s) | Software Result: 0.031777381896972656(s) | Compare: 361.1887008066908
# ====================== 9 qbits, quanv18 circuit ======================
# Hardware Result: 8.7096e-05(s) | Software Result: 0.03632402420043945(s) | Compare: 417.05731836639404
# ====================== 9 qbits, quanv19 circuit ======================
# Hardware Result: 9.8112e-05(s) | Software Result: 0.03764915466308594(s) | Compare: 383.73649159211857
# ====================== 10 qbits, quanv1 circuit ======================
# Hardware Result: 2.2484e-05(s) | Software Result: 0.009145259857177734(s) | Compare: 406.7452347081362
# ====================== 10 qbits, quanv2 circuit ======================
# Hardware Result: 9.2584e-05(s) | Software Result: 0.013249635696411133(s) | Compare: 143.1093460685554
# ====================== 10 qbits, quanv3 circuit ======================
# Hardware Result: 0.000193032(s) | Software Result: 0.030405044555664062(s) | Compare: 157.512974821087
# ====================== 10 qbits, quanv4 circuit ======================
# Hardware Result: 0.000193032(s) | Software Result: 0.030823707580566406(s) | Compare: 159.6818536852253
# ====================== 10 qbits, quanv5 circuit ======================
# Hardware Result: 0.001646236(s) | Software Result: 0.3337571620941162(s) | Compare: 202.73955987726924
# ====================== 10 qbits, quanv6 circuit ======================
# Hardware Result: 0.001648484(s) | Software Result: 0.20187163352966309(s) | Compare: 122.45895837003155
# ====================== 10 qbits, quanv7 circuit ======================
# Hardware Result: 0.00019528(s) | Software Result: 0.03334951400756836(s) | Compare: 170.77792916616326
# ====================== 10 qbits, quanv8 circuit ======================
# Hardware Result: 0.000204272(s) | Software Result: 0.036940813064575195(s) | Compare: 180.84129525620347
# ====================== 10 qbits, quanv9 circuit ======================
# Hardware Result: 9.2584e-05(s) | Software Result: 0.014595270156860352(s) | Compare: 157.6435470152548
# ====================== 10 qbits, quanv10 circuit ======================
# Hardware Result: 0.000123308(s) | Software Result: 0.020130634307861328(s) | Compare: 163.25489269034716
# ====================== 10 qbits, quanv11 circuit ======================
# Hardware Result: 0.000110568(s) | Software Result: 0.018930912017822266(s) | Compare: 171.21510760638037
# ====================== 10 qbits, quanv12 circuit ======================
# Hardware Result: 0.000116188(s) | Software Result: 0.027001142501831055(s) | Compare: 232.391834800763
# ====================== 10 qbits, quanv13 circuit ======================
# Hardware Result: 0.000268404(s) | Software Result: 0.0375516414642334(s) | Compare: 139.907160341252
# ====================== 10 qbits, quanv14 circuit ======================
# Hardware Result: 0.000297628(s) | Software Result: 0.042122602462768555(s) | Compare: 141.52768712207373
# ====================== 10 qbits, quanv15 circuit ======================
# Hardware Result: 0.000129708(s) | Software Result: 0.015478134155273438(s) | Compare: 119.33060532329107
# ====================== 10 qbits, quanv16 circuit ======================
# Hardware Result: 0.0001728(s) | Software Result: 0.031733036041259766(s) | Compare: 183.64025486840143
# ====================== 10 qbits, quanv17 circuit ======================
# Hardware Result: 0.000193032(s) | Software Result: 0.03493618965148926(s) | Compare: 180.98651856422384
# ====================== 10 qbits, quanv18 circuit ======================
# Hardware Result: 0.000190412(s) | Software Result: 0.0861358642578125(s) | Compare: 452.36573460607787
# ====================== 10 qbits, quanv19 circuit ======================
# Hardware Result: 0.000212892(s) | Software Result: 0.04140114784240723(s) | Compare: 194.47019071833242
# ====================== 11 qbits, quanv1 circuit ======================
# Hardware Result: 4.726e-05(s) | Software Result: 0.009539365768432617(s) | Compare: 201.84861972984802
# ====================== 11 qbits, quanv2 circuit ======================
# Hardware Result: 0.000203428(s) | Software Result: 0.01411747932434082(s) | Compare: 69.39791633571004
# ====================== 11 qbits, quanv3 circuit ======================
# Hardware Result: 0.000424036(s) | Software Result: 0.03341102600097656(s) | Compare: 78.7928996617659
# ====================== 11 qbits, quanv4 circuit ======================
# Hardware Result: 0.000424036(s) | Software Result: 0.03305220603942871(s) | Compare: 77.94669801485891
# ====================== 11 qbits, quanv5 circuit ======================
# Hardware Result: 0.003995528(s) | Software Result: 0.4561600685119629(s) | Compare: 114.16765656803379
# ====================== 11 qbits, quanv6 circuit ======================
# Hardware Result: 0.003999824(s) | Software Result: 0.24974465370178223(s) | Compare: 62.43891073751801
# ====================== 11 qbits, quanv7 circuit ======================
# Hardware Result: 0.000426184(s) | Software Result: 0.03688383102416992(s) | Compare: 86.54438229536989
# ====================== 11 qbits, quanv8 circuit ======================
# Hardware Result: 0.000447664(s) | Software Result: 0.04094576835632324(s) | Compare: 91.46540341935747
# ====================== 11 qbits, quanv9 circuit ======================
# Hardware Result: 0.000203428(s) | Software Result: 0.015694618225097656(s) | Compare: 77.15072765350718
# ====================== 11 qbits, quanv10 circuit ======================
# Hardware Result: 0.00026712(s) | Software Result: 0.021600008010864258(s) | Compare: 80.86256368248075
# ====================== 11 qbits, quanv11 circuit ======================
# Hardware Result: 0.000225656(s) | Software Result: 0.020026683807373047(s) | Compare: 88.74873173047935
# ====================== 11 qbits, quanv12 circuit ======================
# Hardware Result: 0.000236396(s) | Software Result: 0.028235435485839844(s) | Compare: 119.44125740638523
# ====================== 11 qbits, quanv13 circuit ======================
# Hardware Result: 0.000572012(s) | Software Result: 0.040457725524902344(s) | Compare: 70.72880555810428
# ====================== 11 qbits, quanv14 circuit ======================
# Hardware Result: 0.000632156(s) | Software Result: 0.04488515853881836(s) | Compare: 71.0032943431975
# ====================== 11 qbits, quanv15 circuit ======================
# Hardware Result: 0.000277416(s) | Software Result: 0.016260623931884766(s) | Compare: 58.61458579131977
# ====================== 11 qbits, quanv16 circuit ======================
# Hardware Result: 0.000381076(s) | Software Result: 0.03525876998901367(s) | Compare: 92.52424710297598
# ====================== 11 qbits, quanv17 circuit ======================
# Hardware Result: 0.000424036(s) | Software Result: 0.03863048553466797(s) | Compare: 91.10190062793718
# ====================== 11 qbits, quanv18 circuit ======================
# Hardware Result: 0.000416096(s) | Software Result: 0.043860673904418945(s) | Compare: 105.40998688864815
# ====================== 11 qbits, quanv19 circuit ======================
# Hardware Result: 0.000463352(s) | Software Result: 0.04618954658508301(s) | Compare: 99.68565277603854
# ====================== 12 qbits, quanv1 circuit ======================
# Hardware Result: 0.000100708(s) | Software Result: 0.010148286819458008(s) | Compare: 100.76942069605204
# ====================== 12 qbits, quanv2 circuit ======================
# Hardware Result: 0.000445344(s) | Software Result: 0.015392303466796875(s) | Compare: 34.56272783914653
# ====================== 12 qbits, quanv3 circuit ======================
# Hardware Result: 0.000928448(s) | Software Result: 0.036507606506347656(s) | Compare: 39.32111061292356
# ====================== 12 qbits, quanv4 circuit ======================
# Hardware Result: 0.000928448(s) | Software Result: 0.03627443313598633(s) | Compare: 39.06996744673512
# ====================== 12 qbits, quanv5 circuit ======================
# Hardware Result: 0.0096006(s) | Software Result: 0.5145514011383057(s) | Compare: 53.59575455058076
# ====================== 12 qbits, quanv6 circuit ======================
# Hardware Result: 0.009571228(s) | Software Result: 0.30260539054870605(s) | Compare: 31.616151088314485
# ====================== 12 qbits, quanv7 circuit ======================
# Hardware Result: 0.00093684(s) | Software Result: 0.04024529457092285(s) | Compare: 42.958557033135705
# ====================== 12 qbits, quanv8 circuit ======================
# Hardware Result: 0.0009788(s) | Software Result: 0.04476284980773926(s) | Compare: 45.73237618281494
# ====================== 12 qbits, quanv9 circuit ======================
# Hardware Result: 0.000445344(s) | Software Result: 0.01712965965270996(s) | Compare: 38.46388331876024
# ====================== 12 qbits, quanv10 circuit ======================
# Hardware Result: 0.000578868(s) | Software Result: 0.02363872528076172(s) | Compare: 40.83612374628019
# ====================== 12 qbits, quanv11 circuit ======================
# Hardware Result: 0.000529264(s) | Software Result: 0.022813081741333008(s) | Compare: 43.103407262411594
# ====================== 12 qbits, quanv12 circuit ======================
# Hardware Result: 0.00055444(s) | Software Result: 0.033186912536621094(s) | Compare: 59.85663468837222
# ====================== 12 qbits, quanv13 circuit ======================
# Hardware Result: 0.001219684(s) | Software Result: 0.04442334175109863(s) | Compare: 36.42200910325841
# ====================== 12 qbits, quanv14 circuit ======================
# Hardware Result: 0.001345564(s) | Software Result: 0.048569679260253906(s) | Compare: 36.09614946613755
# ====================== 12 qbits, quanv15 circuit ======================
# Hardware Result: 0.00059306(s) | Software Result: 0.017543792724609375(s) | Compare: 29.581817564174578
# ====================== 12 qbits, quanv16 circuit ======================
# Hardware Result: 0.000836136(s) | Software Result: 0.03870129585266113(s) | Compare: 46.28588633028733
# ====================== 12 qbits, quanv17 circuit ======================
# Hardware Result: 0.000928448(s) | Software Result: 0.041748046875(s) | Compare: 44.96541203707693
# ====================== 12 qbits, quanv18 circuit ======================
# Hardware Result: 0.000905972(s) | Software Result: 0.04828023910522461(s) | Compare: 53.29109410139012
# ====================== 12 qbits, quanv19 circuit ======================
# Hardware Result: 0.001006676(s) | Software Result: 0.05002784729003906(s) | Compare: 49.69607628476199
# ====================== 13 qbits, quanv1 circuit ======================
# Hardware Result: 0.000215596(s) | Software Result: 0.011107206344604492(s) | Compare: 51.51861047795178
# ====================== 13 qbits, quanv2 circuit ======================
# Hardware Result: 0.000969884(s) | Software Result: 0.016936302185058594(s) | Compare: 17.46219360774958
# ====================== 13 qbits, quanv3 circuit ======================
# Hardware Result: 0.002022684(s) | Software Result: 0.041466474533081055(s) | Compare: 20.50071812160528
# ====================== 13 qbits, quanv4 circuit ======================
# Hardware Result: 0.002022684(s) | Software Result: 0.040452003479003906(s) | Compare: 19.99917114042723
# ====================== 13 qbits, quanv5 circuit ======================
# Hardware Result: 0.02258752(s) | Software Result: 0.631112813949585(s) | Compare: 27.94077499210117
# ====================== 13 qbits, quanv6 circuit ======================
# Hardware Result: 0.022604104(s) | Software Result: 0.37168455123901367(s) | Compare: 16.44323310665239
# ====================== 13 qbits, quanv7 circuit ======================
# Hardware Result: 0.002030976(s) | Software Result: 0.04489874839782715(s) | Compare: 22.106981272958002
# ====================== 13 qbits, quanv8 circuit ======================
# Hardware Result: 0.00213048(s) | Software Result: 0.051491737365722656(s) | Compare: 24.16907803205036
# ====================== 13 qbits, quanv9 circuit ======================
# Hardware Result: 0.000969884(s) | Software Result: 0.018695592880249023(s) | Compare: 19.276112277601264
# ====================== 13 qbits, quanv10 circuit ======================
# Hardware Result: 0.001251064(s) | Software Result: 0.02641892433166504(s) | Compare: 21.11716453487994
# ====================== 13 qbits, quanv11 circuit ======================
# Hardware Result: 0.00108672(s) | Software Result: 0.024908781051635742(s) | Compare: 22.921066191508157
# ====================== 13 qbits, quanv12 circuit ======================
# Hardware Result: 0.001136472(s) | Software Result: 0.03496074676513672(s) | Compare: 30.762523639066092
# ====================== 13 qbits, quanv13 circuit ======================
# Hardware Result: 0.002596444(s) | Software Result: 0.048319101333618164(s) | Compare: 18.609722117487674
# ====================== 13 qbits, quanv14 circuit ======================
# Hardware Result: 0.002861788(s) | Software Result: 0.054125070571899414(s) | Compare: 18.91302590265226
# ====================== 13 qbits, quanv15 circuit ======================
# Hardware Result: 0.001265056(s) | Software Result: 0.019463300704956055(s) | Compare: 15.385327372824644
# ====================== 13 qbits, quanv16 circuit ======================
# Hardware Result: 0.001823676(s) | Software Result: 0.043093204498291016(s) | Compare: 23.62985776985112
# ====================== 13 qbits, quanv17 circuit ======================
# Hardware Result: 0.002022684(s) | Software Result: 0.0478816032409668(s) | Compare: 23.672310277318058
# ====================== 13 qbits, quanv18 circuit ======================
# Hardware Result: 0.001963144(s) | Software Result: 0.0524899959564209(s) | Compare: 26.73772069518125
# ====================== 13 qbits, quanv19 circuit ======================
# Hardware Result: 0.002178736(s) | Software Result: 0.05539131164550781(s) | Compare: 25.423599575858574
# ====================== 14 qbits, quanv1 circuit ======================
# Hardware Result: 0.000461556(s) | Software Result: 0.01290583610534668(s) | Compare: 27.961582354788323
# ====================== 14 qbits, quanv2 circuit ======================
# Hardware Result: 0.002100632(s) | Software Result: 0.02122354507446289(s) | Compare: 10.103409390346759
# ====================== 14 qbits, quanv3 circuit ======================
# Hardware Result: 0.004382584(s) | Software Result: 0.05385279655456543(s) | Compare: 12.287909725076673
# ====================== 14 qbits, quanv4 circuit ======================
# Hardware Result: 0.004382584(s) | Software Result: 0.05431413650512695(s) | Compare: 12.393176378393877
# ====================== 14 qbits, quanv5 circuit ======================
# Hardware Result: 0.052717708(s) | Software Result: 0.8506109714508057(s) | Compare: 16.135203970756955
# ====================== 14 qbits, quanv6 circuit ======================
# Hardware Result: 0.052750676(s) | Software Result: 0.5525498390197754(s) | Compare: 10.47474422924505
# ====================== 14 qbits, quanv7 circuit ======================
# Hardware Result: 0.004415552(s) | Software Result: 0.06146717071533203(s) | Compare: 13.920608502704086
# ====================== 14 qbits, quanv8 circuit ======================
# Hardware Result: 0.00461336(s) | Software Result: 0.06821918487548828(s) | Compare: 14.787310089715149
# ====================== 14 qbits, quanv9 circuit ======================
# Hardware Result: 0.002100632(s) | Software Result: 0.025661468505859375(s) | Compare: 12.216070452063654
# ====================== 14 qbits, quanv10 circuit ======================
# Hardware Result: 0.002693308(s) | Software Result: 0.04031062126159668(s) | Compare: 14.966955603145529
# ====================== 14 qbits, quanv11 circuit ======================
# Hardware Result: 0.002496248(s) | Software Result: 0.04790043830871582(s) | Compare: 19.18897413586944
# ====================== 14 qbits, quanv12 circuit ======================
# Hardware Result: 0.002611636(s) | Software Result: 0.04839658737182617(s) | Compare: 18.53113809574771
# ====================== 14 qbits, quanv13 circuit ======================
# Hardware Result: 0.0055133(s) | Software Result: 0.0636446475982666(s) | Compare: 11.543839007176574
# ====================== 14 qbits, quanv14 circuit ======================
# Hardware Result: 0.006073756(s) | Software Result: 0.07571244239807129(s) | Compare: 12.465506088501298
# ====================== 14 qbits, quanv15 circuit ======================
# Hardware Result: 0.002690716(s) | Software Result: 0.02648162841796875(s) | Compare: 9.841851915240683
# ====================== 14 qbits, quanv16 circuit ======================
# Hardware Result: 0.003954(s) | Software Result: 0.05471396446228027(s) | Compare: 13.837623789145239
# ====================== 14 qbits, quanv17 circuit ======================
# Hardware Result: 0.004382584(s) | Software Result: 0.0621795654296875(s) | Compare: 14.187877615052557
# ====================== 14 qbits, quanv18 circuit ======================
# Hardware Result: 0.004232732(s) | Software Result: 0.06372857093811035(s) | Compare: 15.056131817018027
# ====================== 14 qbits, quanv19 circuit ======================
# Hardware Result: 0.004694284(s) | Software Result: 0.07050108909606934(s) | Compare: 15.018496770981333
# ====================== 15 qbits, quanv1 circuit ======================
# Hardware Result: 0.000986044(s) | Software Result: 0.02234625816345215(s) | Compare: 22.662536523169504
# ====================== 15 qbits, quanv2 circuit ======================
# Hardware Result: 0.004525716(s) | Software Result: 0.04038858413696289(s) | Compare: 8.924241851888826
# ====================== 15 qbits, quanv3 circuit ======================
# Hardware Result: 0.009445844(s) | Software Result: 0.0977168083190918(s) | Compare: 10.344952586459378
# ====================== 15 qbits, quanv4 circuit ======================
# Hardware Result: 0.009445844(s) | Software Result: 0.0979456901550293(s) | Compare: 10.36918354305124
# ====================== 15 qbits, quanv5 circuit ======================
# Hardware Result: 0.121735928(s) | Software Result: 1.1829075813293457(s) | Compare: 9.716996459166483
# ====================== 15 qbits, quanv6 circuit ======================
# Hardware Result: 0.121801664(s) | Software Result: 0.7611739635467529(s) | Compare: 6.249290350801389
# ====================== 15 qbits, quanv7 circuit ======================
# Hardware Result: 0.009478712(s) | Software Result: 0.10721635818481445(s) | Compare: 11.311279231272609
# ====================== 15 qbits, quanv8 circuit ======================
# Hardware Result: 0.009938864(s) | Software Result: 0.1181936264038086(s) | Compare: 11.892065974925162
# ====================== 15 qbits, quanv9 circuit ======================
# Hardware Result: 0.004525716(s) | Software Result: 0.04482555389404297(s) | Compare: 9.904632525338084
# ====================== 15 qbits, quanv10 circuit ======================
# Hardware Result: 0.005773952(s) | Software Result: 0.06612992286682129(s) | Compare: 11.453147318651297
# ====================== 15 qbits, quanv11 circuit ======================
# Hardware Result: 0.005118088(s) | Software Result: 0.06481814384460449(s) | Compare: 12.664523127504744
# ====================== 15 qbits, quanv12 circuit ======================
# Hardware Result: 0.005348164(s) | Software Result: 0.08325457572937012(s) | Compare: 15.566945166485194
# ====================== 15 qbits, quanv13 circuit ======================
# Hardware Result: 0.011674188(s) | Software Result: 0.11187553405761719(s) | Compare: 9.58315336857837
# ====================== 15 qbits, quanv14 circuit ======================
# Hardware Result: 0.012857436(s) | Software Result: 0.1274573802947998(s) | Compare: 9.913125781438834
# ====================== 15 qbits, quanv15 circuit ======================
# Hardware Result: 0.005705624(s) | Software Result: 0.04734086990356445(s) | Compare: 8.29722917310437
# ====================== 15 qbits, quanv16 circuit ======================
# Hardware Result: 0.00852554(s) | Software Result: 0.09745430946350098(s) | Compare: 11.4308664862872
# ====================== 15 qbits, quanv17 circuit ======================
# Hardware Result: 0.009445844(s) | Software Result: 0.11048722267150879(s) | Compare: 11.69691376138636
# ====================== 15 qbits, quanv18 circuit ======================
# Hardware Result: 0.0090828(s) | Software Result: 0.10988855361938477(s) | Compare: 12.098532789380451
# ====================== 15 qbits, quanv19 circuit ======================
# Hardware Result: 0.01006884(s) | Software Result: 0.11819076538085938(s) | Compare: 11.738270285440962
# ====================== 16 qbits, quanv1 circuit ======================
# Hardware Result: 0.002100356(s) | Software Result: 0.09332609176635742(s) | Compare: 44.43346354920662
# ====================== 16 qbits, quanv2 circuit ======================
# Hardware Result: 0.009703312(s) | Software Result: 0.05354189872741699(s) | Compare: 5.517899324211876
# ====================== 16 qbits, quanv3 circuit ======================
# Hardware Result: 0.020259888(s) | Software Result: 0.12537622451782227(s) | Compare: 6.1883967235071715
# ====================== 16 qbits, quanv4 circuit ======================
# Hardware Result: 0.020259888(s) | Software Result: 0.12569713592529297(s) | Compare: 6.204236465931745
# ====================== 16 qbits, quanv5 circuit ======================
# Hardware Result: 0.278474692(s) | Software Result: 1.490248680114746(s) | Compare: 5.351468994944596
# ====================== 16 qbits, quanv6 circuit ======================
# Hardware Result: 0.278605964(s) | Software Result: 1.0811519622802734(s) | Compare: 3.880577238038858
# ====================== 16 qbits, quanv7 circuit ======================
# Hardware Result: 0.02039116(s) | Software Result: 0.1350574493408203(s) | Compare: 6.623333314084158
# ====================== 16 qbits, quanv8 circuit ======================
# Hardware Result: 0.021310064(s) | Software Result: 0.14818334579467773(s) | Compare: 6.953679059559733
# ====================== 16 qbits, quanv9 circuit ======================
# Hardware Result: 0.009703312(s) | Software Result: 0.0565638542175293(s) | Compare: 5.829334789763464
# ====================== 16 qbits, quanv10 circuit ======================
# Hardware Result: 0.012328004(s) | Software Result: 0.08451271057128906(s) | Compare: 6.855344188020142
# ====================== 16 qbits, quanv11 circuit ======================
# Hardware Result: 0.01154112(s) | Software Result: 0.08213400840759277(s) | Compare: 7.11664105455907
# ====================== 16 qbits, quanv12 circuit ======================
# Hardware Result: 0.012066208(s) | Software Result: 0.10898709297180176(s) | Compare: 9.032422859924324
# ====================== 16 qbits, quanv13 circuit ======================
# Hardware Result: 0.02465082(s) | Software Result: 0.13933753967285156(s) | Compare: 5.652450493446123
# ====================== 16 qbits, quanv14 circuit ======================
# Hardware Result: 0.027144988(s) | Software Result: 0.16208148002624512(s) | Compare: 5.970954197004807
# ====================== 16 qbits, quanv15 circuit ======================
# Hardware Result: 0.012062868(s) | Software Result: 0.05977201461791992(s) | Compare: 4.955041754408647
# ====================== 16 qbits, quanv16 circuit ======================
# Hardware Result: 0.018290808(s) | Software Result: 0.11673498153686523(s) | Compare: 6.3821664705498655
# ====================== 16 qbits, quanv17 circuit ======================
# Hardware Result: 0.020259888(s) | Software Result: 0.13634395599365234(s) | Compare: 6.72974875249322
# ====================== 16 qbits, quanv18 circuit ======================
# Hardware Result: 0.019405124(s) | Software Result: 0.1308732032775879(s) | Compare: 6.744260087056794
# ====================== 16 qbits, quanv19 circuit ======================
# Hardware Result: 0.021505476(s) | Software Result: 0.14679837226867676(s) | Compare: 6.826092678379998
# ====================== 17 qbits, quanv1 circuit ======================
# Hardware Result: 0.004459852(s) | Software Result: 0.07571649551391602(s) | Compare: 16.977356090272952
# ====================== 17 qbits, quanv2 circuit ======================
# Hardware Result: 0.020713612(s) | Software Result: 0.1139383316040039(s) | Compare: 5.500650084785016
# ====================== 17 qbits, quanv3 circuit ======================
# Hardware Result: 0.043263628(s) | Software Result: 0.26212573051452637(s) | Compare: 6.0588014143087205
# ====================== 17 qbits, quanv4 circuit ======================
# Hardware Result: 0.043263628(s) | Software Result: 0.2647099494934082(s) | Compare: 6.118533320724009
# ====================== 17 qbits, quanv5 circuit ======================
# Hardware Result: 0.63172376(s) | Software Result: 3.055765390396118(s) | Compare: 4.837186099183793
# ====================== 17 qbits, quanv6 circuit ======================
# Hardware Result: 0.631986104(s) | Software Result: 2.5860447883605957(s) | Compare: 4.091932990287071
# ====================== 17 qbits, quanv7 circuit ======================
# Hardware Result: 0.0433948(s) | Software Result: 0.27176332473754883(s) | Compare: 6.262578113911087
# ====================== 17 qbits, quanv8 circuit ======================
# Hardware Result: 0.045493552(s) | Software Result: 0.3035712242126465(s) | Compare: 6.672840674490453
# ====================== 17 qbits, quanv9 circuit ======================
# Hardware Result: 0.020713612(s) | Software Result: 0.11615657806396484(s) | Compare: 5.607741327971425
# ====================== 17 qbits, quanv10 circuit ======================
# Hardware Result: 0.026222088(s) | Software Result: 0.23831701278686523(s) | Compare: 9.088407177447701
# ====================== 17 qbits, quanv11 circuit ======================
# Hardware Result: 0.023600144(s) | Software Result: 0.17438721656799316(s) | Compare: 7.389243750715807
# ====================== 17 qbits, quanv12 circuit ======================
# Hardware Result: 0.02464952(s) | Software Result: 0.2102646827697754(s) | Compare: 8.530173519394106
# ====================== 17 qbits, quanv13 circuit ======================
# Hardware Result: 0.0519143(s) | Software Result: 0.2765350341796875(s) | Compare: 5.32676033731915
# ====================== 17 qbits, quanv14 circuit ======================
# Hardware Result: 0.05716118(s) | Software Result: 0.3466334342956543(s) | Compare: 6.064140633479825
# ====================== 17 qbits, quanv15 circuit ======================
# Hardware Result: 0.025432464(s) | Software Result: 0.12668418884277344(s) | Compare: 4.981199967206223
# ====================== 17 qbits, quanv16 circuit ======================
# Hardware Result: 0.039066124(s) | Software Result: 0.22022318840026855(s) | Compare: 5.6371906360679285
# ====================== 17 qbits, quanv17 circuit ======================
# Hardware Result: 0.043263628(s) | Software Result: 0.2737240791320801(s) | Compare: 6.326886851284874
# ====================== 17 qbits, quanv18 circuit ======================
# Hardware Result: 0.041294552(s) | Software Result: 0.22872185707092285(s) | Compare: 5.538790130739834
# ====================== 17 qbits, quanv19 circuit ======================
# Hardware Result: 0.0457544(s) | Software Result: 0.2856709957122803(s) | Compare: 6.243574294762476

# %%
import numpy as np
import sys
sys.path.append('..')
from custom_lib import quantum_circuit_ctx_generator, utils, verilog

min_qbit_num = 3
max_qbit_num = 17
min_quantum_circuit_idx = 1
max_quantum_circuit_idx = 19

quantum_circuit_idx_range = np.arange(min_quantum_circuit_idx, max_quantum_circuit_idx+1, 1)
qubit_num_idx_range = np.arange(min_qbit_num, max_qbit_num+1, 1)

hard_results = []
soft_results = []
final_results = []
for qubit_num_idx in qubit_num_idx_range:
    saved_folder_name_hard = '../hardware/verilog/generated_sim_file/quantum_circuit_data_' + str(qubit_num_idx) + '_qubits/'
    for quantum_circuit_idx in quantum_circuit_idx_range:
        saved_sub_folder_name_hard = saved_folder_name_hard + 'quanvolutional_' + str(quantum_circuit_idx)

        hard_data = utils.read_file(saved_sub_folder_name_hard + '/timestamps_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt')
        hard_res = float(hard_data[2].strip("").split(' ')[3][:-3])/1000000000
        res = str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + ": " + str(hard_res) + "(s)"
        hard_results.append(res)

        soft_file_name = "../result/quanv/quanv" + str(quantum_circuit_idx) + ".txt"
        soft_data = utils.read_file(soft_file_name)
        soft_res = float(soft_data[qubit_num_idx-3])
        res = str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + ": " + str(soft_res) + "(s)"
        soft_results.append(res)

        print(f"====================== {qubit_num_idx} qbits, quanv{quantum_circuit_idx} circuit ======================")
        print(f"Hardware Result: {hard_res}(s) | Software Result: {soft_res}(s) | Compare: {soft_res/hard_res}")
        final_results.append(f"====================== {qubit_num_idx} qbits, quanv{quantum_circuit_idx} circuit ======================")
        final_results.append(f"Hardware Result: {hard_res}(s) | Software Result: {soft_res}(s) | Compare: {soft_res/hard_res}")

utils.write_file('hard_results.txt', hard_results)
utils.write_file('soft_results.txt', soft_results)
utils.write_file('final_results.txt', final_results)



# for qubit_num_idx in qubit_num_idx_range:
#     saved_folder = './test_quantum_circuit_data_' + str(qubit_num_idx) + '_qubits/'
#     utils.create_folder(saved_folder)
#     for quantum_circuit_idx in quantum_circuit_idx_range:
#         raw_file_path = saved_folder + 'test_output_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         state_res_file_path = saved_folder + 'test_state_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         processed_file_path = saved_folder + 'test_output_hex_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt'
#         quantum_circuit_ctx_generator.generate_quantum_circuit_data_with_state_res(num_qubits=qubit_num_idx, quanvolutional_idx=quantum_circuit_idx, basis_gate_list=['h', 's', 'cx', 'rx', 'ry', 'rz'], output_file_path=raw_file_path, output_state_path=state_res_file_path)
#         quantum_circuit_ctx_generator.generate_quantum_circuit_ctx(bit_width=32, fraction_width=30, raw_file_path=raw_file_path, processed_file_path=processed_file_path)

# %%
import numpy as np
import sys
sys.path.append('..')
from custom_lib import quantum_circuit_ctx_generator, utils, verilog

# design_folder = "../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/"
# tb_folder = "../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/TB/"

# verilog.hardware_python_sim(design_folder=design_folder, tb_folder=tb_folder)

saved_sub_folder_name = "../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/"
qubit_num_idx = 3
quantum_circuit_idx = 5
data = utils.read_file(saved_sub_folder_name + '/timestamps_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt')
print(data[2].strip("").split(' ')[3])
res = str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + ": " + data[2].strip("").split(' ')[3] + " ns"
# Out:
# 3536000

# %%
import os

# Add library
os.system('vlib work')

# Compile verilog project
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/ALU.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/Comp_Add.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/Comp_Mul.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/COO_Matrix_Generator.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/CX_Swapper.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/Dual_Port_BRAM.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/FX_Add.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/FX_Mul.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/FX_Sub.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/LSU.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/PE_Controller.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/PE.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/PEA.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/QEA_Controller.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/QEA.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/Special_Unit.v')
os.system('vlog ../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/TB/TB_QEA_3_qubits_quanvolutional_5.v')

os.system('vsim -c -do "run -all" TB_QEA_3_qubits_quanvolutional_5')
# Out:
# 1

# %%
# src_folder = '../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/Design/'
# for filename in os.listdir(src_folder):
#     print(filename)
# tb_folder = '../hardware/verilog/generated_sim_file/quantum_circuit_data_3_qubits/quanvolutional_5/TB/'
# sim_files = [f for f in os.listdir(tb_folder)][0]
# print(sim_files)
# Out:
# TB_QEA_3_qubits_quanvolutional_5.v

# %%
# import numpy as np
# import sys
# sys.path.append('..')
# from custom_lib import quantum_circuit_ctx_generator, utils, verilog

# qubit_num_idx = 3
# quantum_circuit_idx = 5
# hex_file = utils.read_file('../hardware/gate_ctx_for_sim/quantum_circuit_data_' + str(qubit_num_idx) + '_qubits/' + 'output_hex_' + str(qubit_num_idx) + '_qubits' + '_quanvolutional_' + str(quantum_circuit_idx) + '.txt')
# print(len(hex_file))
# for i in range(0, len(hex_file)):
#     print(hex_file[i])
# hex_file = hex_file[:-1]
# print(len(hex_file))

# %%
# import numpy as np
# import sys
# sys.path.append('..')
# from custom_lib import quantum_circuit_ctx_generator, utils, verilog

# min_qbit_num = 3
# max_qbit_num = 17
# min_quantum_circuit_idx = 1
# max_quantum_circuit_idx = 19

# create_tb = verilog.create_tb(min_qbit_num, max_qbit_num, min_quantum_circuit_idx, max_quantum_circuit_idx)

# copy_design_files = verilog.copy_design_files(min_qbit_num, max_qbit_num, min_quantum_circuit_idx, max_quantum_circuit_idx)

# %%
# quantum_circuit_idx_range = np.arange(1, 20, 1)
# qubit_num_idx_range = np.arange(3, 18, 1)

# for qubit_num_idx in qubit_num_idx_range:
#     saved_folder = '../hardware/quantum_circuit_data_with_' + str(qubit_num_idx) + '_qubits/'
#     utils.create_folder(saved_folder)
#     for quantum_circuit_idx in quantum_circuit_idx_range:
#         raw_file_path = saved_folder + 'output' + '_quanvolutional' + str(quantum_circuit_idx) + '.txt'
#         processed_file_path = saved_folder + 'output_hex' + '_quanvolutional' + str(quantum_circuit_idx) + '.txt'
#         # print(raw_file_path)
#         # print(processed_file_path)
#         quantum_circuit_ctx_generator.generate_quantum_circuit_data(num_qubits=qubit_num_idx, quanvolutional_idx=quantum_circuit_idx, basis_gate_list=['h', 's', 'cx', 'rx', 'ry', 'rz'], output_file_path=raw_file_path)
#         quantum_circuit_ctx_generator.generate_quantum_circuit_ctx(bit_width=32, fraction_width=30, raw_file_path=raw_file_path, processed_file_path=processed_file_path)
