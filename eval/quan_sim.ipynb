# %%
import numpy as np
import sys
sys.path.append('..')
from custom_lib import quantum_circuit_ctx_generator, utils, verilog, fixed_point_handler

# %%
# def quantum_circuit_computation_local(n_qubit=3, n_quanv=1):
#     ctx_link = '../hardware_material_gen/' + 'output_' + str(n_qubit) + '_qubits' + '_quanvolutional_' + str(n_quanv) + '.txt'
#     gate_ctx_data = utils.read_file(ctx_link)

#     Dense_matrix = np.array([[0, 0], [0, 0]], dtype=complex)

#     state_vector = np.zeros(2**n_qubit, dtype=complex)
#     state_vector[0] = 1

#     bit_width = 32
#     fraction_width = 30

#     sub_idx = 0
#     gate_type = 1 # 0: Sprase, 1: Dense, 2: CX
#     num_of_gates = 0
#     gate_count = 0
#     for index, line in enumerate(gate_ctx_data):
#         if index == 0: # Number of gates
#             num_of_gates = int(line.strip())
#             print(f"=> Number of gates: {num_of_gates}")
#         else:
#             if(sub_idx == 0): # Process gate type
#                 print(f"==================== Gate {gate_count} ====================")
#                 gate_count = gate_count + 1
#                 gate_type = int(line.strip())
#                 sub_idx = sub_idx + 1
#             elif(sub_idx == 1):
#                 if(gate_type == 1): # Process dense gate position
#                     pos = n_qubit-1-int(line.strip())
#                     # pos = int(line.strip())
#                     print(f"====> Dense gate | Pos: {pos}")
#                     sub_idx = sub_idx + 1
#                 elif(gate_type == 2): # Process CX gate position
#                     sub_idx = 0
#                     ctrl_pos, tgt_pos = line.strip("{}").split(", ")
#                     ctrl_pos = n_qubit-1-int(ctrl_pos)
#                     tgt_pos = n_qubit-1-int(tgt_pos)
#                     # ctrl_pos = int(ctrl_pos)
#                     # tgt_pos = int(tgt_pos)

#                     print(f"====> CX gate | Ctrl Pos: {ctrl_pos} | Tgt Pos: {tgt_pos}")

#                     cx_matrix = utils.cx_matrix_formula(n_qubit, ctrl_pos, tgt_pos)
#                     state_vector = np.dot(cx_matrix, state_vector)

#                     print(f"State vector after CX gate:")
#                     for i in range(2**n_qubit):
#                         real_part = state_vector[i].real
#                         imaginary_part = state_vector[i].imag

#                         real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
#                         imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

#                         real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
#                         imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)
#                         print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")
#             else: # Process dense gate entries
#                 if(gate_type):
#                     if(line[0] == '('):
#                         line = line.strip("()")
                        
#                     line = line.strip("")
#                     compl_num = complex(line)

#                     if(sub_idx == 2):
#                         Dense_matrix[0][0] = compl_num
#                     elif(sub_idx == 3):
#                         Dense_matrix[0][1] = compl_num
#                     elif(sub_idx == 4):
#                         Dense_matrix[1][0] = compl_num
#                     elif(sub_idx == 5):
#                         Dense_matrix[1][1] = compl_num

#                         full_dense_matrix = utils.create_full_gate_matrix(gate_matrix=Dense_matrix, gate_pos=pos, n_qubit=n_qubit)
#                         state_vector = np.dot(full_dense_matrix, state_vector)
#                         print(f"State vector after Dense gate:")
#                         for i in range(2**n_qubit):
#                             real_part = state_vector[i].real
#                             imaginary_part = state_vector[i].imag

#                             real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
#                             imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

#                             real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
#                             imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)
#                             print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")

#                     if(sub_idx < 5):
#                         sub_idx = sub_idx + 1
#                     else:
#                         sub_idx = 0


# def quantum_circuit_computation_local_0(n_qubit=3, n_quanv=1):
#     ctx_link = '../hardware/gate_ctx_for_sim/quantum_circuit_data_' + str(n_qubit) + '_qubits/' + 'output_' + str(n_qubit) + '_qubits' + '_quanvolutional_' + str(n_quanv) + '.txt'
#     gate_ctx_data = utils.read_file(ctx_link)

#     I_matrix = np.array([[1, 0], [0, 1]], dtype=complex)
#     Dense_matrix = np.array([[0, 0], [0, 0]], dtype=complex)

#     state_vector = np.zeros(2**n_qubit, dtype=complex)
#     state_vector[0] = 1

#     bit_width = 32
#     fraction_width = 30

#     sub_idx = 0
#     gate_type = 1 # 0: Sprase, 1: Dense, 2: CX
#     num_of_gates = 0
#     gate_count = 0
#     for index, line in enumerate(gate_ctx_data):
#         if index == 0: # Number of gates
#             num_of_gates = int(line.strip())
#             print(f"=> Number of gates: {num_of_gates}")
#         else:
#             if(sub_idx == 0): # Process gate type
#                 print(f"==================== Gate {gate_count} ====================")
#                 gate_count = gate_count + 1
#                 gate_type = int(line.strip())
#                 sub_idx = sub_idx + 1
#             elif(sub_idx == 1):
#                 if(gate_type == 1): # Process dense gate position
#                     pos = n_qubit-1-int(line.strip())
#                     # pos = int(line.strip())
#                     print(f"====> Dense gate | Pos: {pos}")
#                     sub_idx = sub_idx + 1
#                 elif(gate_type == 2): # Process CX gate position
#                     sub_idx = 0
#                     ctrl_pos, tgt_pos = line.strip("{}").split(", ")
#                     ctrl_pos = n_qubit-1-int(ctrl_pos)
#                     tgt_pos = n_qubit-1-int(tgt_pos)
#                     # ctrl_pos = int(ctrl_pos)
#                     # tgt_pos = int(tgt_pos)

#                     print(f"====> CX gate | Ctrl Pos: {ctrl_pos} | Tgt Pos: {tgt_pos}")

#                     cx_matrix = utils.cx_matrix_formula(n_qubit, ctrl_pos, tgt_pos)
#                     state_vector = np.dot(cx_matrix, state_vector)

#                     print(f"State vector after CX gate:")
#                     for i in range(2**n_qubit):
#                         real_part = state_vector[i].real
#                         imaginary_part = state_vector[i].imag

#                         real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
#                         imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

#                         real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
#                         imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)
#                         print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")
#             else: # Process dense gate entries
#                 if(gate_type):
#                     if(line[0] == '('):
#                         line = line.strip("()")
                        
#                     line = line.strip("")
#                     compl_num = complex(line)

#                     if(sub_idx == 2):
#                         Dense_matrix[0][0] = compl_num
#                     elif(sub_idx == 3):
#                         Dense_matrix[0][1] = compl_num
#                     elif(sub_idx == 4):
#                         Dense_matrix[1][0] = compl_num
#                     elif(sub_idx == 5):
#                         Dense_matrix[1][1] = compl_num

#                         full_dense_matrix = utils.create_full_gate_matrix(gate_matrix=Dense_matrix, gate_pos=pos, n_qubit=n_qubit)
#                         state_vector = np.dot(full_dense_matrix, state_vector)
#                         print(f"State vector after Dense gate:")
#                         for i in range(2**n_qubit):
#                             real_part = state_vector[i].real
#                             imaginary_part = state_vector[i].imag

#                             real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
#                             imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

#                             real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
#                             imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)
#                             print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")

#                     if(sub_idx < 5):
#                         sub_idx = sub_idx + 1
#                     else:
#                         sub_idx = 0

def quantum_circuit_computation_qft(n_qubit=3):
    ctx_link = '../hardware/gate_ctx_for_sim/QFT/quantum_circuit_data_' + str(n_qubit) + '_qubits/' + 'output_QFT_' + str(n_qubit) + '_qubits.txt'
    gate_ctx_data = utils.read_file(ctx_link)

    Dense_matrix = np.array([[0, 0], [0, 0]], dtype=complex)

    state_vector = np.zeros(2**n_qubit, dtype=complex)
    state_vector[0] = 1

    bit_width = 32
    fraction_width = 30

    sub_idx = 0
    gate_type = 1 # 0: Sprase, 1: Dense, 2: CX
    num_of_gates = 0
    gate_count = 0
    for index, line in enumerate(gate_ctx_data):
        if index == 0: # Number of gates
            num_of_gates = int(line.strip())
            print(f"=> Number of gates: {num_of_gates}")
        else:
            if(sub_idx == 0): # Process gate type
                print(f"==================== Gate {gate_count} ====================")
                gate_count = gate_count + 1
                gate_type = int(line.strip())
                sub_idx = sub_idx + 1
            elif(sub_idx == 1):
                if(gate_type == 1): # Process dense gate position
                    pos = n_qubit-1-int(line.strip())
                    # pos = int(line.strip())
                    print(f"====> Dense gate | Pos: {pos}")
                    sub_idx = sub_idx + 1
                elif(gate_type == 2): # Process CX gate position
                    sub_idx = 0
                    ctrl_pos, tgt_pos = line.strip("{}").split(", ")
                    ctrl_pos = n_qubit-1-int(ctrl_pos)
                    tgt_pos = n_qubit-1-int(tgt_pos)
                    # ctrl_pos = int(ctrl_pos)
                    # tgt_pos = int(tgt_pos)

                    print(f"====> CX gate | Ctrl Pos: {ctrl_pos} | Tgt Pos: {tgt_pos}")

                    cx_matrix = utils.cx_matrix_formula(n_qubit, ctrl_pos, tgt_pos)
                    state_vector = np.dot(cx_matrix, state_vector)

                    print(f"State vector after CX gate:")
                    for i in range(2**n_qubit):
                        real_part = state_vector[i].real
                        imaginary_part = state_vector[i].imag

                        real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
                        imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

                        real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
                        imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)

                        if(i < 16):
                            print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")
            else: # Process dense gate entries
                if(gate_type):
                    if(line[0] == '('):
                        line = line.strip("()")
                        
                    line = line.strip("")
                    compl_num = complex(line)

                    if(sub_idx == 2):
                        Dense_matrix[0][0] = compl_num
                    elif(sub_idx == 3):
                        Dense_matrix[0][1] = compl_num
                    elif(sub_idx == 4):
                        Dense_matrix[1][0] = compl_num
                    elif(sub_idx == 5):
                        Dense_matrix[1][1] = compl_num

                        full_dense_matrix = utils.create_full_gate_matrix(gate_matrix=Dense_matrix, gate_pos=pos, n_qubit=n_qubit)
                        state_vector = np.dot(full_dense_matrix, state_vector)
                        print(f"State vector after Dense gate:")
                        for i in range(2**n_qubit):
                            real_part = state_vector[i].real
                            imaginary_part = state_vector[i].imag

                            real_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=real_part, bit_width=bit_width, dot_position=fraction_width)
                            imaginary_part_binary = fixed_point_handler.convert_fixedpoint_to_binary(number=imaginary_part, bit_width=bit_width, dot_position=fraction_width)

                            real_part_hex = fixed_point_handler.binary_to_hex(binary_str=real_part_binary, bit_width=bit_width)
                            imaginary_part_hex = fixed_point_handler.binary_to_hex(binary_str=imaginary_part_binary, bit_width=bit_width)

                            # if(i > 255 and i < 264):
                            if(i < 8):
                                print(f"Complex number: {state_vector[i]} | Hex form: {real_part_hex[2:]+imaginary_part_hex[2:]}")

                    if(sub_idx < 5):
                        sub_idx = sub_idx + 1
                    else:
                        sub_idx = 0

# %%
# utils.quantum_circuit_computation(n_qubit=3, n_quanv=6)
quantum_circuit_computation_qft(n_qubit=14)
# Out:
# => Number of gates: 412
# ==================== Gate 0 ====================
# ====> Dense gate | Pos: 13
# State vector after Dense gate:
# Complex number: (0.7071745709502396-0.7070389849232817j) | Hex form: 2d425921d2bfdf8f
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 1 ====================
# ====> Dense gate | Pos: 12
# State vector after Dense gate:
# Complex number: (0.0002876213937631489-0.9999999586369661j) | Hex form: 0004b65fc000002d
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 2 ====================
# ====> Dense gate | Pos: 11
# State vector after Dense gate:
# Complex number: (-0.7066320708875394-0.7075811730064526j) | Hex form: d2c68a48d2b6fd75
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 3 ====================
# ====> Dense gate | Pos: 10
# State vector after Dense gate:
# Complex number: (-0.9999989659243229-0.001438106492939295j) | Hex form: c0000457ffe87025
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 4 ====================
# ====> Dense gate | Pos: 9
# State vector after Dense gate:
# Complex number: (-0.7092052384707264+0.7050020778165697j) | Hex form: d29c61a22d1ec108
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 5 ====================
# ====> Dense gate | Pos: 8
# State vector after Dense gate:
# Complex number: (-0.006040012626656155+0.9999817589573672j) | Hex form: ff9d0a5a3fffb37d
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 6 ====================
# ====> Dense gate | Pos: 7
# State vector after Dense gate:
# Complex number: (0.6984448660326604+0.7156638660101676j) | Hex form: 2cb352182dcd6fd0
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 7 ====================
# ====> Dense gate | Pos: 6
# State vector after Dense gate:
# Complex number: (0.9997011669625088+0.024445383486423666j) | Hex form: 3ffb1a9a0190835e
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 8 ====================
# ====> Dense gate | Pos: 5
# State vector after Dense gate:
# Complex number: (0.7408867370413096-0.6716299895599375j) | Hex form: 2f6ab034d50403a6
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 9 ====================
# ====> Dense gate | Pos: 4
# State vector after Dense gate:
# Complex number: (0.09792172773853663-0.9951941193740548j) | Hex form: 0644597ec04ebd54
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 10 ====================
# ====> Dense gate | Pos: 3
# State vector after Dense gate:
# Complex number: (-0.555649946616825-0.8314163438522966j) | Hex form: dc703b35caca131b
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 11 ====================
# ====> Dense gate | Pos: 2
# State vector after Dense gate:
# Complex number: (-0.9239162175797475-0.3825948547656297j) | Hex form: c4de8e84e78390df
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 12 ====================
# ====> Dense gate | Pos: 1
# State vector after Dense gate:
# Complex number: (-0.9999999954041076+9.58737990952585e-05j) | Hex form: c00000050001921f
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 13 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 14 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 15 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067811865477-5.083146360426727e-16j) | Hex form: d2bec33400000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 16 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067811865477-5.083146360426727e-16j) | Hex form: d2bec33400000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 17 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 18 ====================
# ====> CX gate | Ctrl Pos: 12 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 19 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608-6.77930134793906e-05j) | Hex form: d2bec337fffee3a8
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 20 ====================
# ====> CX gate | Ctrl Pos: 12 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608-6.77930134793906e-05j) | Hex form: d2bec337fffee3a8
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 21 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 22 ====================
# ====> CX gate | Ctrl Pos: 11 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608+6.779301347837397e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 23 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.707106751938466-0.00020337903794459983j) | Hex form: d2bec353fffcaaf8
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 24 ====================
# ====> CX gate | Ctrl Pos: 11 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.707106751938466-0.00020337903794459983j) | Hex form: d2bec353fffcaaf8
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 25 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347837401e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 26 ====================
# ====> CX gate | Ctrl Pos: 10 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347837401e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 27 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071066219469964-0.0004745510594569106j) | Hex form: d2bec3defff83997
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 28 ====================
# ====> CX gate | Ctrl Pos: 10 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071066219469964-0.0004745510594569106j) | Hex form: d2bec3defff83997
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 29 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.707106777936761+6.779301347837409e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 30 ====================
# ====> CX gate | Ctrl Pos: 9 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.707106777936761+6.779301347837409e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 31 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071060499846242-0.0010168948532260334j) | Hex form: d2bec645ffef56d6
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 32 ====================
# ====> CX gate | Ctrl Pos: 9 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071060499846242-0.0010168948532260334j) | Hex form: d2bec645ffef56d6
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 33 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347837404e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 34 ====================
# ====> CX gate | Ctrl Pos: 8 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347837404e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 35 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071036581436482-0.0021015803270786233j) | Hex form: d2bed04dffdd9156
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 36 ====================
# ====> CX gate | Ctrl Pos: 8 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071036581436482-0.0021015803270786233j) | Hex form: d2bed04dffdd9156
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 37 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.707106777936761+6.779301347837382e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 38 ====================
# ====> CX gate | Ctrl Pos: 7 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.707106777936761+6.779301347837382e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 39 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7070938828216062-0.004270933886761201j) | Hex form: d2bef94dffba0668
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 40 ====================
# ====> CX gate | Ctrl Pos: 7 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7070938828216062-0.004270933886761201j) | Hex form: d2bef94dffba0668
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 41 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347837295e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 42 ====================
# ====> CX gate | Ctrl Pos: 6 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347837295e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 43 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7070543660214141-0.00860949998875388j) | Hex form: d2bf9f0cff72f124
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 44 ====================
# ====> CX gate | Ctrl Pos: 6 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7070543660214141-0.00860949998875388j) | Hex form: d2bf9f0cff72f124
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 45 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608+6.779301347837122e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 46 ====================
# ====> CX gate | Ctrl Pos: 5 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608+6.779301347837122e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 47 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.706895474319295-0.01728549643195606j) | Hex form: d2c2397dfee4cb60
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 48 ====================
# ====> CX gate | Ctrl Pos: 5 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.706895474319295-0.01728549643195606j) | Hex form: d2c2397dfee4cb60
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 49 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367608+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 50 ====================
# ====> CX gate | Ctrl Pos: 4 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367608+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 51 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7062583633006236-0.03462837374068622j) | Hex form: d2cca9b9fdc8a613
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 52 ====================
# ====> CX gate | Ctrl Pos: 4 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7062583633006236-0.03462837374068622j) | Hex form: d2cca9b9fdc8a613
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 53 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 54 ====================
# ====> CX gate | Ctrl Pos: 3 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 55 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7037085104063687-0.06924111770942219j) | Hex form: d2f67095fb918db4
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 56 ====================
# ====> CX gate | Ctrl Pos: 3 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7037085104063687-0.06924111770942219j) | Hex form: d2f67095fb918db4
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 57 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 58 ====================
# ====> CX gate | Ctrl Pos: 2 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 59 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.6935331452345608-0.13788319861773582j) | Hex form: d39d2728f72cebf3
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 60 ====================
# ====> CX gate | Ctrl Pos: 2 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.6935331452345608-0.13788319861773582j) | Hex form: d39d2728f72cebf3
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 61 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 62 ====================
# ====> CX gate | Ctrl Pos: 1 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.7071067779367609+6.779301347836775e-05j) | Hex form: d2bec33700011c58
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 63 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.6533074226988652-0.27053541625185906j) | Hex form: d6303611eeaf8c39
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 64 ====================
# ====> CX gate | Ctrl Pos: 1 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.6533074226988652-0.27053541625185906j) | Hex form: d6303611eeaf8c39
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 65 ====================
# ====> Dense gate | Pos: 1
# State vector after Dense gate:
# Complex number: (-0.46195810878987376-0.19129742738281486j) | Hex form: e26f4742f3c1c870
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 66 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 1
# State vector after CX gate:
# Complex number: (-0.46195810878987376-0.19129742738281486j) | Hex form: e26f4742f3c1c870
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 67 ====================
# ====> Dense gate | Pos: 1
# State vector after Dense gate:
# Complex number: (-0.46192141947536186-0.19138600322350374j) | Hex form: e26fe125f3c054ec
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 68 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 1
# State vector after CX gate:
# Complex number: (-0.46192141947536186-0.19138600322350374j) | Hex form: e26fe125f3c054ec
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# Complex number: 0j | Hex form: 0000000000000000
# ==================== Gate 69 ====================
# ====> Dense gate | Pos: 1
# State vector after Dense gate:
# ...
# Complex number: (-0.005524801335548741-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.0055248013355487366-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.0055248013355487366-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# ==================== Gate 402 ====================
# ====> CX gate | Ctrl Pos: 2 | Tgt Pos: 11
# State vector after CX gate:
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548741-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548741-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.0055248013355487366-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.0055248013355487366-0.0055237420697131345j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# ==================== Gate 403 ====================
# ====> CX gate | Ctrl Pos: 11 | Tgt Pos: 2
# State vector after CX gate:
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548741-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548741-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548734-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548734-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548734-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548734-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713138j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548739-0.005523742069713136j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# Complex number: (-0.005524801335548736-0.005523742069713133j) | Hex form: ffa57b4effa57fc0
# ==================== Gate 404 ====================
# ====> Dense gate | Pos: 1
# State vector after Dense gate:
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841772-0.0029890223028564773j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841772-0.0029890223028564773j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# ==================== Gate 405 ====================
# ====> CX gate | Ctrl Pos: 12 | Tgt Pos: 1
# State vector after CX gate:
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# ==================== Gate 406 ====================
# ====> CX gate | Ctrl Pos: 1 | Tgt Pos: 12
# State vector after CX gate:
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# ==================== Gate 407 ====================
# ====> CX gate | Ctrl Pos: 12 | Tgt Pos: 1
# State vector after CX gate:
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841766-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841771-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856478j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.0072180954498417705-0.002989022302856477j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564743j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# Complex number: (-0.007218095449841765-0.0029890223028564778j) | Hex form: ff89bd1effcf0722
# ==================== Gate 408 ====================
# ====> Dense gate | Pos: 0
# State vector after Dense gate:
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# ==================== Gate 409 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554347428e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094574+7.49014055430406e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554299723e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554338755e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554382123e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554343092e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094578+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094576+7.490140554343092e-07j) | Hex form: ff80000100000324
# ==================== Gate 410 ====================
# ====> CX gate | Ctrl Pos: 0 | Tgt Pos: 13
# State vector after CX gate:
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554347428e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094574+7.49014055430406e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554299723e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554338755e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554382123e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554343092e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094578+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094576+7.490140554343092e-07j) | Hex form: ff80000100000324
# ==================== Gate 411 ====================
# ====> CX gate | Ctrl Pos: 13 | Tgt Pos: 0
# State vector after CX gate:
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554347428e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554308397e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094574+7.49014055430406e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554299723e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094584+7.490140554330081e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554338755e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094579+7.490140554382123e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094577+7.490140554343092e-07j) | Hex form: ff80000100000324
# Complex number: (-0.0078124999640945825+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094578+7.490140554312734e-07j) | Hex form: ff80000100000324
# Complex number: (-0.007812499964094576+7.490140554343092e-07j) | Hex form: ff80000100000324
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
